# %% [markdown]
# # Data Preparation: Churn labeling and Downsampling
#
#     1. Read the *play.log files line by line, and write only the user ID, device and date of log into a separate
#     file.
#
#     2. Label churn users: those who played more than three times before the cutoff day but had no acitivity after
#     the cutoff.
#
#     3. Down sampling is necessary. There are more than 500,000 users and 15 GB log data, which is not necessary for
#     the churn prediction and which costs too much time to process. I used  a down sampling ratio of 1/10, to only
#     include 1/10 users from the active and churn users for the churn prediction model.

# %% [markdown]
# ### 1. Churn labeling

# %%
import glob

# %%
filepath = 'C:\\Users\\Sean\\Documents\\BitTiger\\Capston_music_player_python\\data\\play\\*play.log'
files = glob.glob(filepath)
# amount of files
len(files)
# Out:
# 127

# %%
# take a look at one of the files
files[0]
# Out:
# 'C:\\Users\\Sean\\Documents\\BitTiger\\Capston_music_player_python\\data\\play\\20170330_3_play.log'

# %%
# get an idea how many lines are in one .log file
with open(files[0],'r') as f:
    lines = f.readlines()
    log_lines = len(lines)
log_lines
# Out:
# 4760394

# %%
lines[1]
# Out:
# '168540455\tar\t298250\t0\tSee You Again\tMiley Cyrus\t189\t190\t0\n'

# %%
test_list = lines[1].strip('\n').split('\t')
test_list.append(files[0].split('\\')[-1])
test_list
# Out:
# ['168540455',
#  'ar',
#  '298250',
#  '0',
#  'See You Again',
#  'Miley Cyrus',
#  '189',
#  '190',
#  '0',
#  '20170330_3_play.log']

# %%
import pandas as pd

schema = ['uid','device','song_id','song_type','song_name','singer','play_time','song_length','paid_flag','file_name']
df = pd.read_csv('C:\\Users\\Sean\\Documents\\BitTiger\\Capston_music_player_python\\data\\play\\20170330_3_play.log',\
                 delimiter='\t',header=None,index_col=None,names=schema)
df.head()
# Out:
# C:\Users\Sean\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (2,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#            uid device   song_id  song_type      song_name       singer  \
# 0  168550892.0     ar  23491655        0.0             裂心          林志炫
# 1  168540455.0     ar    298250        0.0  See You Again  Miley Cyrus
# 2  168551247.0     ar  11881432        0.0           一梦浮生         颜淡妖妖
# 3  168549788.0     ip    295469        0.0            凡人歌          高胜美
# 4  168551248.0     ip  21393368        0.0      重生（Intro）        幼稚园杀手
#
#   play_time song_length  paid_flag  file_name
# 0       254         254        0.0        NaN
# 1       189         190        0.0        NaN
# 2        78         149        0.0        NaN
# 3        16         242        0.0        NaN
# 4        87          87        0.0        NaN

# %%
df.file_name = files[0].split('\\')[-1]
df.head()
# Out:
#            uid device   song_id  song_type      song_name       singer  \
# 0  168550892.0     ar  23491655        0.0             裂心          林志炫
# 1  168540455.0     ar    298250        0.0  See You Again  Miley Cyrus
# 2  168551247.0     ar  11881432        0.0           一梦浮生         颜淡妖妖
# 3  168549788.0     ip    295469        0.0            凡人歌          高胜美
# 4  168551248.0     ip  21393368        0.0      重生（Intro）        幼稚园杀手
#
#   play_time song_length  paid_flag            file_name
# 0       254         254        0.0  20170330_3_play.log
# 1       189         190        0.0  20170330_3_play.log
# 2        78         149        0.0  20170330_3_play.log
# 3        16         242        0.0  20170330_3_play.log
# 4        87          87        0.0  20170330_3_play.log

# %%
df.loc[df.paid_flag>0]
# Out:
#                  uid device      song_id  song_type  \
# 25285     37025504.0     ar     13068919        0.0
# 238591   168625846.0     ar  5.98923e+06        0.0
# 238754   168625846.0     ar  5.98923e+06        0.0
# 238850   168625846.0     ar  5.98923e+06        0.0
# 238879   168625846.0     ar  5.98923e+06        0.0
# 239279   168625846.0     ar  5.98908e+06        0.0
# 239422   168625846.0     ar  5.98923e+06        0.0
# 239588   168625846.0     ar  5.98908e+06        0.0
# 288398   168667632.0     ar  6.91631e+06        0.0
# 289645   168667632.0     ar  6.91631e+06        0.0
# 428220   168677958.0     ar  6.91631e+06        0.0
# 578396   168637354.0     ar  5.98908e+06        0.0
# 1151416  168721651.0     ip  6.91631e+06        0.0
# 1244993  168806580.0     ar  6.91631e+06        0.0
# 1247437  168721651.0     ip  6.91631e+06        0.0
# 1570351  168715161.0     ar       235500        0.0
# 1580797  169037496.0     ar  5.98925e+06        0.0
# 1676038  168538717.0     ar  5.15763e+06        0.0
# 1920096  168631620.0     ar  5.98914e+06        0.0
# 2217866  168541189.0     ip  6.91631e+06        0.0
# 2712067    1062806.0     ar            0        1.0
# 2712875    1062806.0     ar            0        1.0
# 2713293    1062806.0     ar            0        1.0
# 3090606  168677675.0     ar            0        1.0
# 3111076  168985114.0     ar  6.91631e+06        0.0
# 3119798  168985114.0     ar  6.91631e+06        0.0
# 3150135  168532796.0     ar  6.91631e+06        0.0
# 3178298  168544807.0     ar  6.91631e+06        0.0
# 3198645  168544807.0     ar  6.91631e+06        0.0
# 3203020  168543488.0     ar  6.91631e+06        0.0
# 3208155  168544807.0     ar  6.91631e+06        0.0
# 3218268  168544807.0     ar  6.91631e+06        0.0
# 3356663   94866959.0     ar            0        1.0
# 3362206   94866959.0     ar            0        1.0
# 3373101   94866959.0     ar            0        1.0
# 3778948  168795364.0     ip  6.91631e+06        0.0
# 3954243  168632871.0     ar  6.84759e+06        0.0
# 3956153  168632871.0     ar  1.30689e+07        0.0
# 3956187  168632871.0     ar  1.30689e+07        0.0
# 3960738  168806580.0     ar  6.91631e+06        0.0
# 4018398    1062806.0     ar            0        1.0
# 4018749    1062806.0     ar            0        1.0
# 4018962    1062806.0     ar            0        1.0
# 4019651    1062806.0     ar            0        1.0
# 4020292    1062806.0     ar            0        1.0
# 4104748  168653420.0     ar  6.91631e+06        0.0
# 4263633  168604999.0     ar            0        1.0
# 4669693   82384377.0     ar  6.91631e+06        0.0
#
#                               song_name  \
# 25285    A Theme of ONE PUNCH MAN~正義執行~
# 238591                             153.
# 238754                             153.
# 238850                             153.
# 238879                             153.
# 239279                               2.
# 239422                             153.
# 239588                               2.
# 288398            多少的爱都不要(???? ????????
# 289645            多少的爱都不要(???? ????????
# 428220            多少的爱都不要（???? ????????
# 578396                               2.
# 1151416           多少的爱都不要（???? ????????
# 1244993           多少的爱都不要(???? ????????
# 1247437           多少的爱都不要（???? ????????
# 1570351                              分裂
# 1580797                            169.
# 1676038                        緑眼のジェラシー
# 1920096                             60.
# 2217866           多少的爱都不要（???? ????????
# 2712067                Love Song(Live.)
# 2712875                Love Song(Live.)
# 2713293                Love Song(Live.)
# 3090606          Super Fly ft. G-Dragon
# 3111076           多少的爱都不要(???? ????????
# 3119798           多少的爱都不要(???? ????????
# 3150135           多少的爱都不要(???? ????????
# 3178298           多少的爱都不要(???? ????????
# 3198645           多少的爱都不要(???? ????????
# 3203020           多少的爱都不要（???? ????????
# 3208155           多少的爱都不要(???? ????????
# 3218268           多少的爱都不要(???? ????????
# 3356663                           刘颖、浩楠
# 3362206               牛群、冯巩《明天会更好》（1996
# 3373101               师胜杰、赵宝乐《打传呼》（1997
# 3778948           多少的爱都不要（???? ????????
# 3954243  A Theme Of One Punch Man~正義執行~
# 3956153  A Theme of ONE PUNCH MAN~正義執行~
# 3956187  A Theme of ONE PUNCH MAN~正義執行~
# 3960738           多少的爱都不要(???? ????????
# 4018398                Love Song(Live.)
# 4018749                Love Song(Live.)
# 4018962                Love Song(Live.)
# 4019651                Love Song(Live.)
# 4020292                Love Song(Live.)
# 4104748           多少的爱都不要（???? ????????
# 4263633                               A
# 4669693           多少的爱都不要(???? ????????
#
#                                              singer  \
# 25285                                          宮崎誠"
# 238591                                        ●生活习惯
# 238754                                        ●生活习惯
# 238850                                        ●生活习惯
# 238879                                        ●生活习惯
# 239279                                      ●从起床到出门
# 239422                                        ●生活习惯
# 239588                                      ●从起床到出门
# 288398                                            )
# 289645                                            )
# 428220                                            ）
# 578396                                      ●从起床到出门
# 1151416                                           ）
# 1244993                                           )
# 1247437                                           ）
# 1570351                                        [内地版
# 1580797                          I'm broke.(身无分文。 )
# 1676038                            (東方地霊殿/パルスィのテーマ)
# 1920096  What would you like for dinner? (晚饭你想吃什么?)
# 2217866                                           ）
# 2712067                                     Bigbang
# 2712875                                     Bigbang
# 2713293                                     Bigbang
# 3090606                                       T.O.P
# 3111076                                           )
# 3119798                                           )
# 3150135                                           )
# 3178298                                           )
# 3198645                                           )
# 3203020                                           ）
# 3208155                                           )
# 3218268                                           )
# 3356663                                 《一对一》（2011）
# 3362206                                           ）
# 3373101                                           ）
# 3778948                                           ）
# 3954243                                        宮崎誠"
# 3956153                                        宮崎誠"
# 3956187                                        宮崎誠"
# 3960738                                           )
# 4018398                                     Bigbang
# 4018749                                     Bigbang
# 4018962                                     Bigbang
# 4019651                                     Bigbang
# 4020292                                     Bigbang
# 4104748                                           ）
# 4263633                                     5s(DJH)
# 4669693                                           )
#
#                                           play_time song_length  paid_flag  \
# 25285                                            \t          \t      128.0
# 238591                                   分级加字幕轻松练听力           2        3.0
# 238754                                   分级加字幕轻松练听力           2        3.0
# 238850                                   分级加字幕轻松练听力           2        3.0
# 238879                                   分级加字幕轻松练听力           0        3.0
# 239279                                   分级加字幕轻松练听力          10        9.0
# 239422                                   分级加字幕轻松练听力           2        3.0
# 239588                                   分级加字幕轻松练听力           2        9.0
# 288398                                  Ten Nararak         168      415.0
# 289645                                  Ten Nararak           0      415.0
# 428220                                  Ten Nararak           1      415.0
# 578396                                   分级加字幕轻松练听力           6        9.0
# 1151416                                 Ten Nararak          55      415.0
# 1244993                                 Ten Nararak         217      415.0
# 1247437                                 Ten Nararak           1      415.0
# 1570351                                         周杰伦           0      252.0
# 1580797                                  分级加字幕轻松练听力           3        7.0
# 1676038                                    はちみつくまさん           4      262.0
# 1920096                                  分级加字幕轻松练听力           6        7.0
# 2217866                                 Ten Nararak         415      415.0
# 2712067                                         NaN        3123      276.0
# 2712875                                         NaN      275841      276.0
# 2713293                                         NaN      276102      276.0
# 3090606              & &#53468;&#50577; of Big Bang        Lexy        9.0
# 3111076                                 Ten Nararak          13      415.0
# 3119798                                 Ten Nararak          36      415.0
# 3150135                                 Ten Nararak         348      415.0
# 3178298                                 Ten Nararak         262      415.0
# 3198645                                 Ten Nararak         414      415.0
# 3203020                                 Ten Nararak         414      415.0
# 3208155                                 Ten Nararak         413      415.0
# 3218268                                 Ten Nararak         415      415.0
# 3356663                                        未知歌手           0      465.0
# 3362206                                        未知歌手           0      494.0
# 3373101                                        未知歌手           0      325.0
# 3778948                                 Ten Nararak         415      415.0
# 3954243  \tTVアニメ『ワンパンマン』オリジナルサウンドトラック「One Take Man」           8      107.0
# 3956153                                          \t          \t      128.0
# 3956187                                          \t          \t      128.0
# 3960738                                 Ten Nararak         333      415.0
# 4018398                                         NaN      276102      276.0
# 4018749                                         NaN      275841      276.0
# 4018962                                         NaN      275841      276.0
# 4019651                                         NaN      275841      276.0
# 4020292                                         NaN      275841      276.0
# 4104748                                 Ten Nararak           0      415.0
# 4263633                                       Dance          39      241.0
# 4669693                                 Ten Nararak         415      415.0
#
#                    file_name
# 25285    20170330_3_play.log
# 238591   20170330_3_play.log
# 238754   20170330_3_play.log
# 238850   20170330_3_play.log
# 238879   20170330_3_play.log
# 239279   20170330_3_play.log
# 239422   20170330_3_play.log
# 239588   20170330_3_play.log
# 288398   20170330_3_play.log
# 289645   20170330_3_play.log
# 428220   20170330_3_play.log
# 578396   20170330_3_play.log
# 1151416  20170330_3_play.log
# 1244993  20170330_3_play.log
# 1247437  20170330_3_play.log
# 1570351  20170330_3_play.log
# 1580797  20170330_3_play.log
# 1676038  20170330_3_play.log
# 1920096  20170330_3_play.log
# 2217866  20170330_3_play.log
# 2712067  20170330_3_play.log
# 2712875  20170330_3_play.log
# 2713293  20170330_3_play.log
# 3090606  20170330_3_play.log
# 3111076  20170330_3_play.log
# 3119798  20170330_3_play.log
# 3150135  20170330_3_play.log
# 3178298  20170330_3_play.log
# 3198645  20170330_3_play.log
# 3203020  20170330_3_play.log
# 3208155  20170330_3_play.log
# 3218268  20170330_3_play.log
# 3356663  20170330_3_play.log
# 3362206  20170330_3_play.log
# 3373101  20170330_3_play.log
# 3778948  20170330_3_play.log
# 3954243  20170330_3_play.log
# 3956153  20170330_3_play.log
# 3956187  20170330_3_play.log
# 3960738  20170330_3_play.log
# 4018398  20170330_3_play.log
# 4018749  20170330_3_play.log
# 4018962  20170330_3_play.log
# 4019651  20170330_3_play.log
# 4020292  20170330_3_play.log
# 4104748  20170330_3_play.log
# 4263633  20170330_3_play.log
# 4669693  20170330_3_play.log

# %%
def to_num(s):
    try:
        return float(s)
    except ValueError:
        return s
    
[to_num(string) for string in [12.0,'1.234','I-love-coding']]
# Out:
# [12.0, 1.234, 'I-love-coding']

# %%
def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        return False
    
def not_number(s):
    try:
        float(s)
        return False
    except ValueError:
        return True
    
df.loc[df.play_time.apply(not_number)]
# Out:
#                  uid device      song_id  song_type  \
# 22       168551408.0     ar     15750838        2.0
# 199      168546522.0     ar      5820473        2.0
# 243      168544206.0     ar     23134997        2.0
# 1223     168547035.0     ar      2835290        2.0
# 1639     168551256.0     ar      1952511        2.0
# 2027     168544206.0     ar     22399294        2.0
# 2476     168551256.0     ar      3462716        2.0
# 2724     168550027.0     ar      2834716        2.0
# 3082     168544206.0     ar     22943011        2.0
# 3746     168551619.0     ar      6661512        2.0
# 4155     168546725.0     ar       462233        2.0
# 5036     168546522.0     ar      5836892        2.0
# 5849     168544206.0     ar     20864795        2.0
# 6176     168548474.0     ar     22943011        2.0
# 6205     168548474.0     ar      6692408        2.0
# 6770     168548474.0     ar     23496116        2.0
# 7258     168548474.0     ar      6692408        2.0
# 7424     168531371.0     ar     20980836        2.0
# 7668     168546522.0     ar      5836892        2.0
# 7964     168462415.0     ar     20980634        2.0
# 8036     168547485.0     ar       298250        2.0
# 8279     168546522.0     ar      3967159        2.0
# 8369     168544206.0     ar     20864790        2.0
# 8576     168552306.0     ar     20272130        2.0
# 8669     168547485.0     ar       811133        2.0
# 8741     168546522.0     ar      3973129        2.0
# 9100     168546522.0     ar      3227311        2.0
# 9612     168546522.0     ar      1875760        2.0
# 10313    168546522.0     ar      3488723        2.0
# 10341    168547485.0     ar       478338        2.0
# ...              ...    ...          ...        ...
# 4754613  168664409.0     ar  1.41316e+07        2.0
# 4754811          0.0     ar  2.09807e+07        2.0
# 4755015  169022082.0     ar  1.52413e+07        2.0
# 4755023  169017552.0     ar  3.41692e+06        2.0
# 4755195  168539357.0     ar  6.47961e+06        2.0
# 4755209  168809341.0     ar  2.00352e+07        2.0
# 4755238  169018257.0     ar  3.10840e+06        2.0
# 4755411  168922560.0     ar        43594        3.0
# 4755734  169019497.0     ar  1.69108e+06        2.0
# 4755892  169016021.0     ar  3.43909e+06        2.0
# 4756057   37025504.0     ar  3.25675e+06        2.0
# 4756128  169017453.0     ar       454511        2.0
# 4756295  169022366.0     ar  7.18992e+06        2.0
# 4756321  168747681.0     ar  7.20111e+06        2.0
# 4756635  169017552.0     ar  3.43309e+06        2.0
# 4756689          0.0     ar  2.18303e+07        2.0
# 4757265  168961860.0     ar  1.11566e+07        2.0
# 4757416  168971375.0     ar  1.39247e+07        2.0
# 4757642  168922560.0     ar        42380        3.0
# 4758225  169022366.0     ar  7.10816e+06        2.0
# 4758284  169017240.0     ar  4.81641e+06        2.0
# 4758664  169011409.0     ar  2.30376e+07        2.0
# 4759010  169017552.0     ar  4.14766e+06        2.0
# 4759109  169021343.0     ar   1.6889e+07        2.0
# 4759422  169021978.0     ar  2.23996e+07        2.0
# 4759658  168887753.0     ar  2.34961e+07        2.0
# 4759893  168650472.0     ar  2.14617e+07        2.0
# 4760300  169021978.0     ar  2.23997e+07        2.0
# 4760472  169021343.0     ar  2.00352e+07        2.0
# 4760574  168723674.0     ar  6.12146e+06        2.0
#
#                                                  song_name  \
# 22                                                      惊雷
# 199                                       Out Of The Woods
# 243                                    从嘲笑到震撼!不能更赞!有梦想就要坚持
# 1223                                          江南Style(纽约版)
# 1639     Feels So Good (Tristan Garner Remix) (feat. Na...
# 2027                         一群火烈鸟走迷路了，仿佛看到了路痴的我。。。这特么是哪儿？
# 2476                                            Feat Sophi
# 2724                                                    城门
# 3082                             哈哈哈谁都别拦我!这个泰坦尼克的COS我要给满分!
# 3746                                       男神版《从前的我》回归那份感动
# 4155                                              我和草原有个约定
# 5036                                        Wildest Dreams
# 5849                                  用中国风演绎话题剧曲目~花郎-非你不可~
# 6176                             哈哈哈谁都别拦我!这个泰坦尼克的COS我要给满分!
# 6205                                      虫儿飞-(电影《我是证人》插曲)
# 6770                                   小刺猬一秒前还怒气满满,见到食物后……
# 7258                                      虫儿飞-(电影《我是证人》插曲)
# 7424                    【易烊千玺】世界上怎么会有这么可爱的蓝孩子呢~棒棒糖Lollipop
# 7668                                        Wildest Dreams
# 7964                           元气满满！雪爷x幽爷孑然妒火(在狂风大作的天台捉迷藏)
# 8036                                         See You Again
# 8279                                           Begin Again
# 8369                                       感人至深的恋曲，深情的钢琴演奏
# 8576                                 【亮剑】李云龙RAP你这政委怎么当的!!!
# 8669                                           Bye Bye Bye
# 8741                                                  Ours
# 9100               We Are Never Ever Getting Back Together
# 9612                                        Safe And Sound
# 10313                                        Never Grow Up
# 10341                                           Just Dance
# ...                                                    ...
# 4754613                               富贵花开-(网络电影《神笔马娘》推广曲)
# 4754811                                    太享受！来听听电音中的桂林山水
# 4755015                   【暖心】一头叫艾玛的牛以为自己上了屠宰场的车泪流不止，没想到……
# 4755023                                           Youtopia
# 4755195                                    年轮-(电视剧《花千骨》插曲)
# 4755209                                      如听仙乐！《天黑黑》钢琴版
# 4755238                                             Mirage
# 4755411                               韩宝仪专辑最经典全集，喜欢听歌的不容错过
# 4755734                                               西海情歌
# 4755892                                         异乡人(2013版)
# 4756057                                            欢乐年年庆友谊
# 4756128                                               新年快乐
# 4756295                                    Wonderland(舞蹈版)
# 4756321                                           Paradise
# 4756635              Waiting For The Night (International)
# 4756689                                              敲 喜欢你
# 4757265                                       On Your Side
# 4757416                                            欧舒丹 饭制版
# 4757642                     这才是Beyond现场版最最经典的《大地》，家驹的尾奏太经典
# 4758225                                        Set Me Free
# 4758284                              Nice Body(Dance Ver.)
# 4758664                             弟弟用门帮姐姐压腿,最后一句话亮了哈哈哈哈!
# 4759010      This Is What It Feels Like (Uk Radio Version)
# 4759109                                       无敌可爱！舞法天女的尬舞
# 4759422                                               酒色财气
# 4759658                       尴尬癌！新闻联播结束前因为时常不够,主播只好尬到最后……
# 4759893                              Go Off-(电影《速度与激情8》插曲)
# 4760300                                                春天里
# 4760472                                      如听仙乐！《天黑黑》钢琴版
# 4760574                                               红尘蝶恋
#
#                                   singer                  play_time  \
# 22                                 MC王小五       7>(123.138.230.80)TM
# 199                         Taylor Swift      23>(113.68.113.130)TM
# 243                                  NaN     71>=(223.104.12.211)TM
# 1223                                 Psy    111>=(223.85.150.140)TM
# 1639                    Armin van Buuren      4>}(113.82.176.86)TM
# 2027                                热门短片    43>}(223.104.12.211)TM
# 2476                    Armin van Buuren      0>}(113.82.176.86)TM
# 2724                                 陈浩民    0>}(113.200.107.141)TM
# 3082                                 NaN       5>(223.104.12.211)TM
# 3746                                 NaN      5>}(113.82.176.86)TM
# 4155                                降央卓玛      5>}(110.153.68.24)TM
# 5036                        Taylor Swift       4>(113.68.113.130)TM
# 5849                                 NaN    14>}(223.104.12.211)TM
# 6176                                 NaN    5>}(115.214.138.235)TM
# 6205                                  鹿晗    5>}(115.214.138.235)TM
# 6770                                 NaN      5>(115.214.138.235)TM
# 7258                                  鹿晗      5>(115.214.138.235)TM
# 7424                               丸子小千千       10>(116.7.204.119)TM
# 7668                        Taylor Swift     158>(113.68.113.130)TM
# 7964                             雪爷珞雪是位爷       17>(117.136.16.25)TM
# 8036                         Miley Cyrus    11>}(223.214.39.194)TM
# 8279                        Taylor Swift       4>(113.68.113.130)TM
# 8369                                 NaN     25>=(223.104.12.211)TM
# 8576                                 NaN         62>(1.71.83.126)TM
# 8669                          Lovestoned       5>(223.214.39.194)TM
# 8741                        Taylor Swift     24>=(113.68.113.130)TM
# 9100                        Taylor Swift     22>=(113.68.113.130)TM
# 9612                        Taylor Swift      52>(113.68.113.130)TM
# 10313                       Taylor Swift     66>=(113.68.113.130)TM
# 10341                          Lady GaGa     5>}(223.214.39.194)TM
# ...                                  ...                        ...
# 4754613                            王麟&安琥     0>}(106.117.47.108)TM
# 4754811                     SnikmOffical    46>=(222.210.230.150)TM
# 4755015                             热门短片     10>=(42.238.145.113)TM
# 4755023        Armin van Buuren&Owl City       28>=(182.86.202.4)TM
# 4755195                              张碧晨      30>(183.165.152.56)TM
# 4755209                              小鸭子         0>=(36.4.103.11)TM
# 4755238                 Armin van Buuren      11>(117.136.80.111)TM
# 4755411                              NaN  8170>}(42.236.133.163)TM
# 4755734                             降央卓玛      42>(39.148.226.199)TM
# 4755892                               李健     189>=(221.205.89.56)TM
# 4756057                              刘姝辰      29>}(27.46.23.100)TM
# 4756128                              卓依婷    198>}(223.104.31.32)TM
# 4756295                          gu9udan    29>=(183.193.132.180)TM
# 4756321                      Hello Venus   112>}(180.143.76.231)TM
# 4756635           Armin van Buuren&Fiora        39>(182.86.202.4)TM
# 4756689                           严艺丹&叶青   200>=(222.210.230.150)TM
# 4757265                    The Veronicas       5>=(218.26.205.26)TM
# 4757416                              薛之谦         53>(58.22.11.52)TM
# 4757642                              NaN    254>=(42.236.133.163)TM
# 4758225                       Team A[日本]   75>}(183.193.132.180)TM
# 4758284                              朴孝敏          4>(1.84.179.78)TM
# 4758664                              NaN        0>(117.136.79.80)TM
# 4759010  Armin van Buuren&Trevor Guthrie       68>=(182.86.202.4)TM
# 4759109                           有咩酱×乐歌       5>(223.104.12.229)TM
# 4759422                              NaN      13>(124.237.184.42)TM
# 4759658                              NaN     44>=(121.235.190.80)TM
# 4759893  Lil Uzi Vert&Quavo&Travis Scott         0>(60.28.201.13)TM
# 4760300                              NaN       1>(124.237.184.42)TM
# 4760472                              小鸭子       4>(223.104.12.229)TM
# 4760574                           安东阳&时嘉     4>}(114.91.172.173)TM
#
#         song_length  paid_flag            file_name
# 22                0        0.0  20170330_3_play.log
# 199             256        0.0  20170330_3_play.log
# 243             157        0.0  20170330_3_play.log
# 1223              0        0.0  20170330_3_play.log
# 1639            371        0.0  20170330_3_play.log
# 2027             80        0.0  20170330_3_play.log
# 2476            219        0.0  20170330_3_play.log
# 2724            240        0.0  20170330_3_play.log
# 3082             32        0.0  20170330_3_play.log
# 3746              0        0.0  20170330_3_play.log
# 4155            221        0.0  20170330_3_play.log
# 5036            234        0.0  20170330_3_play.log
# 5849            243        0.0  20170330_3_play.log
# 6176              0        0.0  20170330_3_play.log
# 6205              0        0.0  20170330_3_play.log
# 6770              0        0.0  20170330_3_play.log
# 7258              0        0.0  20170330_3_play.log
# 7424            269        0.0  20170330_3_play.log
# 7668            234        0.0  20170330_3_play.log
# 7964            213        0.0  20170330_3_play.log
# 8036            193        0.0  20170330_3_play.log
# 8279            250        0.0  20170330_3_play.log
# 8369            103        0.0  20170330_3_play.log
# 8576             94        0.0  20170330_3_play.log
# 8669            186        0.0  20170330_3_play.log
# 8741            246        0.0  20170330_3_play.log
# 9100            215        0.0  20170330_3_play.log
# 9612            240        0.0  20170330_3_play.log
# 10313           290        0.0  20170330_3_play.log
# 10341           246        0.0  20170330_3_play.log
# ...             ...        ...                  ...
# 4754613         232        0.0  20170330_3_play.log
# 4754811         124        0.0  20170330_3_play.log
# 4755015         106        0.0  20170330_3_play.log
# 4755023         199        0.0  20170330_3_play.log
# 4755195         273        0.0  20170330_3_play.log
# 4755209         393        0.0  20170330_3_play.log
# 4755238         191        0.0  20170330_3_play.log
# 4755411        9954        0.0  20170330_3_play.log
# 4755734         250        0.0  20170330_3_play.log
# 4755892         226        0.0  20170330_3_play.log
# 4756057           0        0.0  20170330_3_play.log
# 4756128         204        0.0  20170330_3_play.log
# 4756295         188        0.0  20170330_3_play.log
# 4756321         212        0.0  20170330_3_play.log
# 4756635         198        0.0  20170330_3_play.log
# 4756689         238        0.0  20170330_3_play.log
# 4757265         246        0.0  20170330_3_play.log
# 4757416         223        0.0  20170330_3_play.log
# 4757642         264        0.0  20170330_3_play.log
# 4758225         219        0.0  20170330_3_play.log
# 4758284         210        0.0  20170330_3_play.log
# 4758664           0        0.0  20170330_3_play.log
# 4759010         249        0.0  20170330_3_play.log
# 4759109         237        0.0  20170330_3_play.log
# 4759422        2561        0.0  20170330_3_play.log
# 4759658          65        0.0  20170330_3_play.log
# 4759893         217        0.0  20170330_3_play.log
# 4760300         482        0.0  20170330_3_play.log
# 4760472         230        0.0  20170330_3_play.log
# 4760574         244        0.0  20170330_3_play.log
#
# [29534 rows x 10 columns]

# %%
# 04/22 is the cutoff date for labeling churns
cutoff = '20170422'

# %% [markdown]
# ##### Save reduced play logs to two log files.
#
# Only the first two items of each line, user id and device, and the date of the log are saved, so it's called reduced play logs.

# %%
# destination file names to save the reduced logs.
first_period_log = 'C:\\Users\\Sean\\Documents\\BitTiger\\Capston_music_player_python\\data\\play_till_0421.log'
second_period_log = 'C:\\Users\\Sean\\Documents\\BitTiger\\Capston_music_player_python\\data\\play_till_0512.log'

# %%
import time

for each_file in files:
    current_time = time.clock()

    with open(each_file, 'r') as f:
        lines = f.readlines()
        filename = f.name.split('\\')[-1]
        print('processing file: %s' % filename)
        #choose the output path
        if filename < cutoff:
            output_path = first_period_log
        else:
            output_path = second_period_log
        # write to the output file
        with open(output_path, 'a') as output:
            for line in lines:
                contents_to_keep = line.split('\t')[:2]
                contents_to_keep.append(filename)
                output.write('\t'.join(contents_to_keep)+'\n')
    print('...costs %.2f seconds' % (time.clock()-current_time))
    current_time = time.clock()
# Out:
# processing file: 20170330_3_play.log
# ...costs 10.36 seconds
# processing file: 20170331_1_play.log
# ...costs 5.20 seconds
# processing file: 20170331_2_play.log
# ...costs 3.71 seconds
# processing file: 20170331_3_play.log
# ...costs 8.27 seconds
# processing file: 20170401_1_play.log
# ...costs 5.08 seconds
# processing file: 20170401_2_play.log
# ...costs 5.43 seconds
# processing file: 20170401_3_play.log
# ...costs 6.07 seconds
# processing file: 20170402_1_play.log
# ...costs 5.55 seconds
# processing file: 20170402_2_play.log
# ...costs 4.91 seconds
# processing file: 20170402_3_play.log
# ...costs 5.78 seconds
# processing file: 20170403_1_play.log
# ...costs 5.41 seconds
# processing file: 20170403_2_play.log
# ...costs 5.11 seconds
# processing file: 20170404_1_play.log
# ...costs 4.93 seconds
# processing file: 20170404_2_play.log
# ...costs 4.10 seconds
# processing file: 20170404_3_play.log
# ...costs 0.65 seconds
# processing file: 20170405_1_play.log
# ...costs 0.13 seconds
# processing file: 20170405_2_play.log
# ...costs 3.70 seconds
# processing file: 20170405_3_play.log
# ...costs 3.50 seconds
# processing file: 20170406_1_play.log
# ...costs 0.12 seconds
# processing file: 20170406_2_play.log
# ...costs 3.29 seconds
# processing file: 20170406_3_play.log
# ...costs 3.88 seconds
# processing file: 20170407_1_play.log
# ...costs 3.47 seconds
# processing file: 20170407_2_play.log
# ...costs 3.50 seconds
# processing file: 20170407_3_play.log
# ...costs 3.82 seconds
# processing file: 20170408_1_play.log
# ...costs 3.60 seconds
# processing file: 20170408_2_play.log
# ...costs 3.69 seconds
# processing file: 20170408_3_play.log
# ...costs 4.09 seconds
# processing file: 20170409_1_play.log
# ...costs 3.74 seconds
# processing file: 20170409_2_play.log
# ...costs 3.54 seconds
# processing file: 20170409_3_play.log
# ...costs 3.68 seconds
# processing file: 20170410_1_play.log
# ...costs 3.11 seconds
# processing file: 20170410_2_play.log
# ...costs 3.00 seconds
# processing file: 20170410_3_play.log
# ...costs 2.84 seconds
# processing file: 20170411_1_play.log
# ...costs 3.27 seconds
# processing file: 20170411_2_play.log
# ...costs 3.53 seconds
# processing file: 20170412_1_play.log
# ...costs 2.93 seconds
# processing file: 20170412_2_play.log
# ...costs 3.49 seconds
# processing file: 20170412_3_play.log
# ...costs 3.13 seconds
# processing file: 20170413_1_play.log
# ...costs 2.80 seconds
# processing file: 20170413_2_play.log
# ...costs 3.57 seconds
# processing file: 20170413_3_play.log
# ...costs 2.92 seconds
# processing file: 20170414_1_play.log
# ...costs 1.78 seconds
# processing file: 20170414_2_play.log
# ...costs 1.60 seconds
# processing file: 20170414_3_play.log
# ...costs 1.52 seconds
# processing file: 20170415_1_play.log
# ...costs 3.48 seconds
# processing file: 20170415_2_play.log
# ...costs 3.10 seconds
# processing file: 20170415_3_play.log
# ...costs 4.25 seconds
# processing file: 20170416_1_play.log
# ...costs 3.57 seconds
# processing file: 20170416_2_play.log
# ...costs 2.97 seconds
# processing file: 20170416_3_play.log
# ...costs 3.49 seconds
# processing file: 20170417_1_play.log
# ...costs 2.83 seconds
# processing file: 20170417_2_play.log
# ...costs 2.60 seconds
# processing file: 20170418_1_play.log
# ...costs 2.51 seconds
# processing file: 20170418_2_play.log
# ...costs 3.21 seconds
# processing file: 20170418_3_play.log
# ...costs 3.40 seconds
# processing file: 20170419_1_play.log
# ...costs 3.35 seconds
# processing file: 20170419_2_play.log
# ...costs 3.09 seconds
# processing file: 20170419_3_play.log
# ...costs 2.47 seconds
# processing file: 20170420_1_play.log
# ...costs 2.88 seconds
# processing file: 20170420_2_play.log
# ...costs 2.41 seconds
# processing file: 20170420_3_play.log
# ...costs 3.34 seconds
# processing file: 20170421_1_play.log
# ...costs 2.78 seconds
# processing file: 20170421_2_play.log
# ...costs 2.99 seconds
# processing file: 20170421_3_play.log
# ...costs 2.77 seconds
# processing file: 20170422_1_play.log
# ...costs 3.30 seconds
# processing file: 20170422_2_play.log
# ...costs 2.94 seconds
# processing file: 20170422_3_play.log
# ...costs 2.89 seconds
# processing file: 20170423_1_play.log
# ...costs 3.34 seconds
# processing file: 20170423_2_play.log
# ...costs 1.94 seconds
# processing file: 20170423_3_play.log
# ...costs 2.90 seconds
# processing file: 20170424_1_play.log
# ...costs 1.66 seconds
# processing file: 20170424_2_play.log
# ...costs 0.33 seconds
# processing file: 20170424_3_play.log
# ...costs 2.41 seconds
# processing file: 20170425_1_play.log
# ...costs 2.74 seconds
# processing file: 20170425_2_play.log
# ...costs 2.56 seconds
# processing file: 20170425_3_play.log
# ...costs 2.78 seconds
# processing file: 20170426_1_play.log
# ...costs 2.66 seconds
# processing file: 20170426_2_play.log
# ...costs 2.80 seconds
# processing file: 20170426_3_play.log
# ...costs 2.41 seconds
# processing file: 20170427_1_play.log
# ...costs 2.69 seconds
# processing file: 20170427_2_play.log
# ...costs 2.24 seconds
# processing file: 20170427_3_play.log
# ...costs 3.23 seconds
# processing file: 20170428_1_play.log
# ...costs 2.37 seconds
# processing file: 20170428_2_play.log
# ...costs 2.63 seconds
# processing file: 20170428_3_play.log
# ...costs 2.39 seconds
# processing file: 20170429_1_play.log
# ...costs 3.11 seconds
# processing file: 20170429_2_play.log
# ...costs 2.92 seconds
# processing file: 20170429_3_play.log
# ...costs 3.09 seconds
# processing file: 20170430_1_play.log
# ...costs 2.69 seconds
# processing file: 20170430_2_play.log
# ...costs 3.03 seconds
# processing file: 20170430_3_play.log
# ...costs 3.09 seconds
# processing file: 20170501_1_play.log
# ...costs 2.49 seconds
# processing file: 20170501_2_play.log
# ...costs 3.12 seconds
# processing file: 20170501_3_play.log
# ...costs 2.65 seconds
# processing file: 20170502_1_play.log
# ...costs 2.28 seconds
# processing file: 20170502_2_play.log
# ...costs 2.37 seconds
# processing file: 20170502_3_play.log
# ...costs 2.05 seconds
# processing file: 20170503_1_play.log
# ...costs 2.44 seconds
# processing file: 20170503_2_play.log
# ...costs 2.35 seconds
# processing file: 20170503_3_play.log
# ...costs 2.26 seconds
# processing file: 20170504_1_play.log
# ...costs 2.15 seconds
# processing file: 20170504_2_play.log
# ...costs 2.33 seconds
# processing file: 20170504_3_play.log
# ...costs 2.13 seconds
# processing file: 20170505_1_play.log
# ...costs 2.33 seconds
# processing file: 20170505_2_play.log
# ...costs 2.62 seconds
# processing file: 20170505_3_play.log
# ...costs 2.24 seconds
# processing file: 20170506_1_play.log
# ...costs 2.09 seconds
# processing file: 20170506_2_play.log
# ...costs 3.16 seconds
# processing file: 20170506_3_play.log
# ...costs 2.98 seconds
# processing file: 20170507_1_play.log
# ...costs 2.38 seconds
# processing file: 20170507_2_play.log
# ...costs 2.95 seconds
# processing file: 20170507_3_play.log
# ...costs 2.15 seconds
# processing file: 20170508_1_play.log
# ...costs 2.62 seconds
# processing file: 20170508_2_play.log
# ...costs 2.45 seconds
# processing file: 20170508_3_play.log
# ...costs 2.21 seconds
# processing file: 20170509_1_play.log
# ...costs 2.66 seconds
# processing file: 20170509_2_play.log
# ...costs 2.56 seconds
# processing file: 20170509_3_play.log
# ...costs 2.30 seconds
# processing file: 20170510_1_play.log
# ...costs 2.53 seconds
# processing file: 20170510_2_play.log
# ...costs 2.52 seconds
# processing file: 20170510_3_play.log
# ...costs 1.92 seconds
# processing file: 20170511_1_play.log
# ...costs 2.53 seconds
# processing file: 20170511_2_play.log
# ...costs 2.61 seconds
# processing file: 20170511_3_play.log
# ...costs 2.79 seconds
# processing file: 20170512_1_play.log
# ...costs 2.79 seconds
# processing file: 20170512_2_play.log
# ...costs 2.94 seconds
# processing file: 20170512_3_play.log
# ...costs 2.53 seconds

# %%
import pandas as pd

schema = ['uid','device','file_name']
df_1 = pd.read_csv(first_period_log,delimiter='\t',header=None,index_col=None,names=schema, dtype = {'uid':'str'})
df_1.head()
# Out:
#          uid device            file_name
# 0  168550892     ar  20170330_3_play.log
# 1  168540455     ar  20170330_3_play.log
# 2  168551247     ar  20170330_3_play.log
# 3  168549788     ip  20170330_3_play.log
# 4  168551248     ip  20170330_3_play.log

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82001784 entries, 0 to 82001783
# Data columns (total 3 columns):
# uid          object
# device       object
# file_name    object
# dtypes: object(3)
# memory usage: 1.8+ GB

# %% [markdown]
# ##### Label active users in the first period.
#
#     Criteria: number of activities before the cutoff > 3

# %%
df_1.uid.value_counts()
# Out:
# 1685126      3617414
# 37025504     2613945
# 751824       2097443
# 1791497      1888301
# 497685       1393958
# 1062806      1164170
# 736305        856422
# 0             568498
# 1749320       372206
# 1679121       244088
# 46532274      233379
# 28638487      200651
# 637650        108488
# 155948236      97851
# 32166203       74229
# 533817         74064
# 64268006       65829
# 168127634      35003
# 22730453       31866
# 16517426       31675
# 32104145       29951
# 924065         29727
# 168922214      29260
# 167982849      28483
# 27954505       24917
# 1710083        23176
# 165313253      21655
# 168674332      17807
# 168751924      17717
# 168334631      16474
#               ...
# 167731479          1
# 168763247          1
# 168859231          1
# 168804426          1
# 168761136          1
# 169022327          1
# 168969919          1
# 168546198          1
# 168444376          1
# 168546199          1
# 168801780          1
# 168801781          1
# 168001689          1
# 167931183          1
# 168791070          1
# 168934216          1
# 168791075          1
# 168961109          1
# 168399126          1
# 169001697          1
# 168761130          1
# 168486670          1
# 168704857          1
# 168704855          1
# 168103059          1
# 168258503          1
# 168402656          1
# 168504640          1
# 168581116          1
# 168684368          1
# Name: uid, Length: 564624, dtype: int64

# %%
# total number of active users and inactive users
active = df_1.uid.value_counts()>3
sum(active),sum(active==0)
# Out:
# (472632, 91992)

# %%
active_users = [active.index[i] for i in xrange(len(active)) if active[i]]
active_users[:5]
# Out:
# ['1685126', '37025504', '751824', '1791497', '497685']

# %%
active_set_1 = set(active_users)

# %%
df_2 = pd.read_csv(second_period_log,delimiter='\t',header=None,index_col=None,names=schema, dtype = {'uid':'str'})
df_2.head()
# Out:
#          uid device            file_name
# 0     751824     ar  20170422_1_play.log
# 1  167806444     ar  20170422_1_play.log
# 2   28638487     ar  20170422_1_play.log
# 3  167854540     ar  20170422_1_play.log
# 4    1685126     ar  20170422_1_play.log

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56753407 entries, 0 to 56753406
# Data columns (total 3 columns):
# uid          object
# device       object
# file_name    object
# dtypes: object(3)
# memory usage: 1.3+ GB

# %%
active_2 = df_2.uid.value_counts()
active_2[:5]
# Out:
# 1685126     3531544
# 37025504    2570137
# 751824      2221580
# 497685      1518085
# 1791497     1325354
# Name: uid, dtype: int64

# %%
active_set_2 = set(active_2.index)
len(active_set_2)
# Out:
# 272501

# %%
churn_set = active_set_1 - active_set_2
len(churn_set)
# Out:
# 238889

# %%
good_set = active_set_1 & active_set_2
len(good_set)
# Out:
# 233743

# %% [markdown]
# ### Down Sampling

# %%
import random

random.seed(42)

# %%
good_sample = random.sample(good_set,len(good_set)/10)
len(good_sample)
# Out:
# 23374

# %%
churn_sample = random.sample(churn_set,len(churn_set)/10)
len(churn_sample)
# Out:
# 23888

# %%
df_churn_log = df_1.loc[df_1.uid.isin(churn_sample),:]

# %%
df_churn_log.shape
# Out:
# (1507639, 3)

# %%
df_good_log = df_1.loc[df_1.uid.isin(good_sample),:]

# %%
df_good_log.shape
# Out:
# (7577773, 3)

# %%
df_churn_log.head()
# Out:
#           uid device            file_name
# 23  168551179     ar  20170330_3_play.log
# 34  168551221     ar  20170330_3_play.log
# 45  168551397     ar  20170330_3_play.log
# 66  168549013     ip  20170330_3_play.log
# 76  168543049     ar  20170330_3_play.log

# %% [markdown]
# #####  play with the logs, and create features for churn prediction
#
#     just a few examples

# %%
df_good_log.groupby(['uid','file_name']).size()
# Out:
# uid        file_name
# 100415077  20170331_1_play.log     39
#            20170402_1_play.log      3
#            20170403_1_play.log     13
#            20170408_1_play.log     31
#            20170411_1_play.log     13
#            20170415_1_play.log     32
#            20170417_1_play.log      7
#            20170418_1_play.log     66
#            20170419_1_play.log      1
#            20170420_1_play.log     27
# 100549339  20170331_2_play.log     62
#            20170401_2_play.log     19
#            20170402_2_play.log     13
#            20170403_2_play.log     54
#            20170404_2_play.log     14
#            20170405_2_play.log     23
#            20170406_2_play.log     23
#            20170407_2_play.log     27
#            20170408_2_play.log      7
#            20170409_2_play.log      9
#            20170410_2_play.log      2
#            20170412_2_play.log      9
#            20170413_2_play.log      9
#            20170414_2_play.log      2
#            20170415_2_play.log     21
#            20170416_2_play.log     81
#            20170417_2_play.log      1
#            20170418_2_play.log     22
#            20170419_2_play.log     47
#            20170420_2_play.log     76
#                                  ...
# 98574751   20170401_1_play.log     50
#            20170402_1_play.log     27
#            20170403_1_play.log    118
#            20170404_1_play.log     42
#            20170407_1_play.log     68
#            20170408_1_play.log     37
#            20170409_1_play.log    112
#            20170410_1_play.log     95
#            20170411_1_play.log    151
#            20170415_1_play.log      6
#            20170416_1_play.log      7
#            20170417_1_play.log    101
#            20170418_1_play.log     76
#            20170419_1_play.log     73
#            20170420_1_play.log     80
#            20170421_1_play.log    304
# 99651190   20170330_3_play.log    190
#            20170331_3_play.log    129
#            20170401_3_play.log      8
#            20170402_3_play.log     35
#            20170405_3_play.log     10
#            20170406_3_play.log     10
#            20170409_3_play.log     34
#            20170410_3_play.log      1
#            20170412_3_play.log    111
#            20170415_3_play.log     24
# 99725077   20170330_3_play.log     12
#            20170401_3_play.log     12
#            20170405_3_play.log      1
#            20170406_3_play.log      1
# Length: 188303, dtype: int64

# %%
df_daily_good = df_good_log.groupby(['uid','file_name']).size().to_frame(name = 'count').reset_index()
df_daily_good.head()
# Out:
#          uid            file_name  count
# 0  100415077  20170331_1_play.log     39
# 1  100415077  20170402_1_play.log      3
# 2  100415077  20170403_1_play.log     13
# 3  100415077  20170408_1_play.log     31
# 4  100415077  20170411_1_play.log     13

# %%
df_device_good = df_good_log.groupby(['uid','device']).size().to_frame(name = 'count').reset_index()
df_device_good.head()
# Out:
#          uid device  count
# 0  100415077     ar    232
# 1  100549339     ar    534
# 2  101372876     ar    328
# 3  102311569     ar    359
# 4  102393511     ar    356

# %%
import numpy as np

df_churn_log['date'] = df_churn_log.file_name.str.split('_').apply(lambda x: x[0])
df_churn_log.head()
# Out:
# C:\Users\Sean\Anaconda2\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#           uid device            file_name      date
# 23  168551179     ar  20170330_3_play.log  20170330
# 34  168551221     ar  20170330_3_play.log  20170330
# 45  168551397     ar  20170330_3_play.log  20170330
# 66  168549013     ip  20170330_3_play.log  20170330
# 76  168543049     ar  20170330_3_play.log  20170330

# %%
df_churn_log.loc[:,'label'] = 1
df_churn_log.head()
# Out:
# C:\Users\Sean\Anaconda2\lib\site-packages\pandas\core\indexing.py:337: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\Sean\Anaconda2\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#           uid device            file_name      date  label
# 23  168551179     ar  20170330_3_play.log  20170330      1
# 34  168551221     ar  20170330_3_play.log  20170330      1
# 45  168551397     ar  20170330_3_play.log  20170330      1
# 66  168549013     ip  20170330_3_play.log  20170330      1
# 76  168543049     ar  20170330_3_play.log  20170330      1

# %%
df_good_log['date'] = df_good_log.file_name.str.split('_').apply(lambda x: x[0])
df_good_log.head()
# Out:
# C:\Users\Sean\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#            uid device            file_name      date
# 61   168534518     ar  20170330_3_play.log  20170330
# 80      751824     ar  20170330_3_play.log  20170330
# 99   168551186     ar  20170330_3_play.log  20170330
# 129  168548840     ip  20170330_3_play.log  20170330
# 135  168547123     ar  20170330_3_play.log  20170330

# %%
df_good_log.loc[:,'label'] = 0
df_good_log.head()
# Out:
#            uid device            file_name      date  label
# 61   168534518     ar  20170330_3_play.log  20170330      0
# 80      751824     ar  20170330_3_play.log  20170330      0
# 99   168551186     ar  20170330_3_play.log  20170330      0
# 129  168548840     ip  20170330_3_play.log  20170330      0
# 135  168547123     ar  20170330_3_play.log  20170330      0

# %%
df_complete = pd.concat([df_good_log,df_churn_log])
df_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9085412 entries, 61 to 82001380
# Data columns (total 5 columns):
# uid          object
# device       object
# file_name    object
# date         object
# label        int64
# dtypes: int64(1), object(4)
# memory usage: 415.9+ MB

# %%
df_complete.label.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df_complete.date.unique()
# Out:
# array(['20170330', '20170331', '20170401', '20170402', '20170403',
#        '20170404', '20170405', '20170406', '20170407', '20170408',
#        '20170409', '20170410', '20170411', '20170412', '20170413',
#        '20170414', '20170415', '20170416', '20170417', '20170418',
#        '20170419', '20170420', '20170421'], dtype=object)

# %% [markdown]
# ##### paid_flag
#     Take care of user who PAY !!!

# %%
import numpy as np
import pandas as pd
schema = ['uid','device','song_id','song_type','song_name','singer','play_time','song_length','paid_flag','file_name']
df_paid_user = pd.DataFrame(columns = schema)
df_paid_user.head()
# Out:
# Empty DataFrame
# Columns: [uid, device, song_id, song_type, song_name, singer, play_time, song_length, paid_flag, file_name]
# Index: []

# %%
with open('t.ini') as f:
    for line in f:

# %%
import time

current_time = time.clock()
for each_file in files:
    filename = each_file.split('\\')[-1]
    print('processing file: %s' % filename)
    df_temp = pd.read_csv(each_file,delimiter='\t',header=None,index_col=None,names=schema)
    df_temp.file_name = filename
    df_temp = df_temp.loc[df_temp.paid_flag>0]
    df_paid_user = df_paid_user.append(df_temp)
    print('...costs %.2f seconds' % (time.clock()-current_time))
    current_time = time.clock()
    
df_paid_user.shape
# Out:
# processing file: 20170330_3_play.log
# ...costs 13.74 seconds
# processing file: 20170331_1_play.log
# ...costs 5.27 seconds
# processing file: 20170331_2_play.log
# ...costs 3.61 seconds
# processing file: 20170331_3_play.log
# ...costs 8.49 seconds
# processing file: 20170401_1_play.log
# ...costs 7.32 seconds
# processing file: 20170401_2_play.log
# ...costs 7.08 seconds
# processing file: 20170401_3_play.log
# ...costs 17.15 seconds
# processing file: 20170402_1_play.log
# ...costs 13.81 seconds
# processing file: 20170402_2_play.log
# ...costs 12.03 seconds
# processing file: 20170402_3_play.log
# ...costs 25.76 seconds
# processing file: 20170403_1_play.log
# ...costs 25.05 seconds
# processing file: 20170403_2_play.log
# ...costs 31.32 seconds
# processing file: 20170404_1_play.log
# ...costs 28.06 seconds
# processing file: 20170404_2_play.log
# ...costs 10.32 seconds
# processing file: 20170404_3_play.log
# ...costs 1.33 seconds
# processing file: 20170405_1_play.log
# ...costs 0.69 seconds
# processing file: 20170405_2_play.log
# ...costs 17.11 seconds
# processing file: 20170405_3_play.log
# ...costs 6.46 seconds
# processing file: 20170406_1_play.log
# ...costs 0.50 seconds
# processing file: 20170406_2_play.log
# ...costs 7.87 seconds
# processing file: 20170406_3_play.log
# ...costs 105.10 seconds
# processing file: 20170407_1_play.log
# ...costs 4.58 seconds
# processing file: 20170407_2_play.log
# ...costs 4.58 seconds
# processing file: 20170407_3_play.log
# ...costs 4.63 seconds
# processing file: 20170408_1_play.log
# ...costs 4.58 seconds
# processing file: 20170408_2_play.log
# ...costs 4.81 seconds
# processing file: 20170408_3_play.log
# ...costs 4.34 seconds
# processing file: 20170409_1_play.log
# ...costs 4.35 seconds
# processing file: 20170409_2_play.log
# ...costs 5.21 seconds
# processing file: 20170409_3_play.log
# ...costs 4.02 seconds
# processing file: 20170410_1_play.log
# ...costs 5.49 seconds
# processing file: 20170410_2_play.log
# ...costs 4.19 seconds
# processing file: 20170410_3_play.log
# ...costs 4.80 seconds
# processing file: 20170411_1_play.log
# ...costs 4.78 seconds
# processing file: 20170411_2_play.log
# ...costs 7.81 seconds
# processing file: 20170412_1_play.log
# ...costs 5.20 seconds
# processing file: 20170412_2_play.log
# ...costs 10.85 seconds
# processing file: 20170412_3_play.log
# ...costs 13.13 seconds
# processing file: 20170413_1_play.log
# ...costs 5.00 seconds
# processing file: 20170413_2_play.log
# ...costs 5.39 seconds
# processing file: 20170413_3_play.log
# ...costs 4.00 seconds
# processing file: 20170414_1_play.log
# ...costs 10.79 seconds
# processing file: 20170414_2_play.log
# ...costs 3.28 seconds
# processing file: 20170414_3_play.log
# ...costs 5.85 seconds
# processing file: 20170415_1_play.log
# ...costs 93.89 seconds
# processing file: 20170415_2_play.log
# ...costs 5.56 seconds
# processing file: 20170415_3_play.log
# ...costs 4.65 seconds
# processing file: 20170416_1_play.log
# ...costs 4.87 seconds
# processing file: 20170416_2_play.log
# ...costs 5.62 seconds
# processing file: 20170416_3_play.log
# ...costs 4.38 seconds
# processing file: 20170417_1_play.log
# ...costs 4.02 seconds
# processing file: 20170417_2_play.log
# ...costs 3.40 seconds
# processing file: 20170418_1_play.log
# ...costs 3.01 seconds
# processing file: 20170418_2_play.log
# ...costs 3.44 seconds
# processing file: 20170418_3_play.log
# ...costs 3.33 seconds
# processing file: 20170419_1_play.log
# ...costs 4.20 seconds
# processing file: 20170419_2_play.log
# ...costs 3.91 seconds
# processing file: 20170419_3_play.log
# ...costs 6.55 seconds
# processing file: 20170420_1_play.log
# ...costs 3.46 seconds
# processing file: 20170420_2_play.log
# ...costs 3.20 seconds
# processing file: 20170420_3_play.log
# ...costs 3.28 seconds
# processing file: 20170421_1_play.log
# ...costs 3.99 seconds
# processing file: 20170421_2_play.log
# ...costs 5.98 seconds
# processing file: 20170421_3_play.log
# ...costs 8.39 seconds
# processing file: 20170422_1_play.log
# ...costs 11.28 seconds
# processing file: 20170422_2_play.log
# ...costs 16.19 seconds
# processing file: 20170422_3_play.log
# ...costs 7.27 seconds
# processing file: 20170423_1_play.log
# ...costs 13.98 seconds
# processing file: 20170423_2_play.log
# ...costs 22.71 seconds
# processing file: 20170423_3_play.log
# ...costs 5.63 seconds
# processing file: 20170424_1_play.log
# ...costs 2.43 seconds
# processing file: 20170424_2_play.log
# ...costs 0.64 seconds
# processing file: 20170424_3_play.log
# ...costs 3.87 seconds
# processing file: 20170425_1_play.log
# ...costs 3.81 seconds
# processing file: 20170425_2_play.log
# ...costs 4.27 seconds
# processing file: 20170425_3_play.log
# ...costs 3.88 seconds
# processing file: 20170426_1_play.log
# ...costs 3.50 seconds
# processing file: 20170426_2_play.log
# ...costs 3.36 seconds
# processing file: 20170426_3_play.log
# ...costs 3.00 seconds
# processing file: 20170427_1_play.log
# ...costs 2.93 seconds
# processing file: 20170427_2_play.log
# ...costs 3.88 seconds
# processing file: 20170427_3_play.log
# ...costs 4.34 seconds
# processing file: 20170428_1_play.log
# ...costs 3.44 seconds
# processing file: 20170428_2_play.log
# ...costs 3.82 seconds
# processing file: 20170428_3_play.log
# ...costs 3.14 seconds
# processing file: 20170429_1_play.log
# ...costs 3.23 seconds
# processing file: 20170429_2_play.log
# ...costs 5.88 seconds
# processing file: 20170429_3_play.log
# ...costs 4.39 seconds
# processing file: 20170430_1_play.log
# ...costs 3.47 seconds
# processing file: 20170430_2_play.log
# ...costs 4.36 seconds
# processing file: 20170430_3_play.log
# ...costs 5.31 seconds
# processing file: 20170501_1_play.log
# ...costs 7.08 seconds
# processing file: 20170501_2_play.log
# ...costs 4.37 seconds
# processing file: 20170501_3_play.log
# ...costs 3.76 seconds
# processing file: 20170502_1_play.log
# ...costs 2.80 seconds
# processing file: 20170502_2_play.log
# ...costs 2.88 seconds
# processing file: 20170502_3_play.log
# ...costs 2.76 seconds
# processing file: 20170503_1_play.log
# ...costs 3.03 seconds
# processing file: 20170503_2_play.log
# ...costs 3.06 seconds
# processing file: 20170503_3_play.log
# ...costs 3.20 seconds
# processing file: 20170504_1_play.log
# ...costs 3.07 seconds
# processing file: 20170504_2_play.log
# ...costs 2.99 seconds
# processing file: 20170504_3_play.log
# ...costs 2.96 seconds
# processing file: 20170505_1_play.log
# ...costs 2.83 seconds
# processing file: 20170505_2_play.log
# ...costs 3.07 seconds
# processing file: 20170505_3_play.log
# ...costs 2.97 seconds
# processing file: 20170506_1_play.log
# ...costs 1.94 seconds
# processing file: 20170506_2_play.log
# ...costs 2.68 seconds
# processing file: 20170506_3_play.log
# ...costs 6.10 seconds
# processing file: 20170507_1_play.log
# ...costs 4.15 seconds
# processing file: 20170507_2_play.log
# ...costs 4.27 seconds
# processing file: 20170507_3_play.log
# ...costs 3.01 seconds
# processing file: 20170508_1_play.log
# ...costs 6.06 seconds
# processing file: 20170508_2_play.log
# ...costs 7.72 seconds
# processing file: 20170508_3_play.log
# ...costs 6.22 seconds
# processing file: 20170509_1_play.log
# ...costs 6.56 seconds
# processing file: 20170509_2_play.log
# ...costs 3.45 seconds
# processing file: 20170509_3_play.log
# ...costs 6.66 seconds
# processing file: 20170510_1_play.log
# ...costs 4.22 seconds
# processing file: 20170510_2_play.log
# ...costs 5.44 seconds
# processing file: 20170510_3_play.log
# ...costs 3.58 seconds
# processing file: 20170511_1_play.log
# ...costs 3.53 seconds
# processing file: 20170511_2_play.log
# ...costs 3.37 seconds
# processing file: 20170511_3_play.log
# ...costs 3.26 seconds
# processing file: 20170512_1_play.log
# ...costs 3.01 seconds
# processing file: 20170512_2_play.log
# ...costs 2.61 seconds
# processing file: 20170512_3_play.log
# ...costs 2.72 seconds
# (133439, 10)

# %%
df_temp = df_temp.loc[df_temp.paid_flag>0]
df_temp.shape
# Out:
# (10, 10)

# %%
df_paid_user.head()
# Out:
#                 uid device      song_id song_type              song_name  \
# 52804   1.68533e+08     ar  6.91631e+06         0  多少的爱都不要(???? ????????
# 285061  1.68905e+08     ip  6.91631e+06         0  多少的爱都不要（???? ????????
# 285083  1.68905e+08     ip  6.91631e+06         0  多少的爱都不要（???? ????????
# 315778  1.68681e+08     ip  6.91631e+06         0  多少的爱都不要（???? ????????
# 324711  1.68757e+08     ar  6.91631e+06         0  多少的爱都不要(???? ????????
#
#        singer    play_time song_length paid_flag file_name
# 52804       )  Ten Nararak          35       415         0
# 285061      ）  Ten Nararak         415       415         0
# 285083      ）  Ten Nararak         415       415         0
# 315778      ）  Ten Nararak         415       415         0
# 324711      )  Ten Nararak         414       415         0

# %%
df_check = df_paid_user.loc[df_paid_user.play_time.apply(is_number) & df_paid_user.play_time.notnull()]
df_check.paid_flag.value_counts()
# Out:
# 0    129843
# Name: paid_flag, dtype: int64

# %%
df_paid_user.device.value_counts()
# Out:
# ar           116180
# ip            17258
# 168589573         1
# Name: device, dtype: int64

# %%
del df_paid_user

# %% [markdown]
# ##### Conclusion: no real paid users

# %% [markdown]
# ##### check non-iphone or android users

# %%
df_temp.loc[df_temp.device.apply(lambda x: x!= 'ar' and x != 'ip')]
# Out:
# Empty DataFrame
# Columns: [uid, device, song_id, song_type, song_name, singer, play_time, song_length, paid_flag, file_name]
# Index: []

# %%
import numpy as np
import pandas as pd
import time

schema = ['uid','device','song_id','song_type','song_name','singer','play_time','song_length','paid_flag','file_name']

df_device = pd.DataFrame(columns = schema)
current_time = time.clock()
for each_file in files:
    filename = each_file.split('\\')[-1]
    print('processing file: %s' % filename)
    df_temp = pd.read_csv(each_file,delimiter='\t',header=None,index_col=None,names=schema)
    df_temp.file_name = filename
    df_temp = df_temp.loc[df_temp.device.apply(lambda x: x!= 'ar' and x != 'ip')]
    df_device = df_device.append(df_temp)
    print('...costs %.2f seconds' % (time.clock()-current_time))
    current_time = time.clock()
    
df_device.shape
# Out:
# processing file: 20170330_3_play.log
# C:\Users\Sean\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (2,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ...costs 11.21 seconds
# processing file: 20170331_1_play.log
# C:\Users\Sean\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ...costs 4.42 seconds
# processing file: 20170331_2_play.log
# ...costs 3.28 seconds
# processing file: 20170331_3_play.log
# ...costs 7.24 seconds
# processing file: 20170401_1_play.log
# ...costs 7.14 seconds
# processing file: 20170401_2_play.log
# C:\Users\Sean\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ...costs 4.49 seconds
# processing file: 20170401_3_play.log
# ...costs 5.18 seconds
# processing file: 20170402_1_play.log
# ...costs 17.19 seconds
# processing file: 20170402_2_play.log
# ...costs 3.75 seconds
# processing file: 20170402_3_play.log
# ...costs 7.00 seconds
# processing file: 20170403_1_play.log
# ...costs 5.27 seconds
# processing file: 20170403_2_play.log
# ...costs 4.86 seconds
# processing file: 20170404_1_play.log
# ...costs 14.03 seconds
# processing file: 20170404_2_play.log
# ...costs 78.49 seconds
# processing file: 20170404_3_play.log
# ...costs 1.20 seconds
# processing file: 20170405_1_play.log
# ...costs 0.38 seconds
# processing file: 20170405_2_play.log
# C:\Users\Sean\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (2,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ...costs 4.12 seconds
# processing file: 20170405_3_play.log
# ...costs 4.13 seconds
# processing file: 20170406_1_play.log
# ...costs 0.23 seconds
# processing file: 20170406_2_play.log
# ...costs 3.75 seconds
# processing file: 20170406_3_play.log
# ...costs 3.93 seconds
# processing file: 20170407_1_play.log
# ...costs 4.34 seconds
# processing file: 20170407_2_play.log
# ...costs 4.34 seconds
# processing file: 20170407_3_play.log
# C:\Users\Sean\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (2,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ...costs 4.88 seconds
# processing file: 20170408_1_play.log
# ...costs 4.27 seconds
# processing file: 20170408_2_play.log
# C:\Users\Sean\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (0,2,3,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ...costs 6.08 seconds
# processing file: 20170408_3_play.log
# ...costs 4.21 seconds
# processing file: 20170409_1_play.log
# ...costs 4.35 seconds
# processing file: 20170409_2_play.log
# C:\Users\Sean\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (0,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ...costs 4.88 seconds
# processing file: 20170409_3_play.log
# ...costs 4.70 seconds
# processing file: 20170410_1_play.log
# ...costs 4.10 seconds
# processing file: 20170410_2_play.log
# C:\Users\Sean\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (0,2,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ...costs 8.70 seconds
# processing file: 20170410_3_play.log
# ...costs 3.78 seconds
# processing file: 20170411_1_play.log
# ...costs 4.10 seconds
# processing file: 20170411_2_play.log
# ...costs 5.17 seconds
# processing file: 20170412_1_play.log
# ...costs 13.37 seconds
# processing file: 20170412_2_play.log
# ...costs 5.51 seconds
# processing file: 20170412_3_play.log
# ...costs 4.05 seconds
# processing file: 20170413_1_play.log
# ...costs 3.53 seconds
# processing file: 20170413_2_play.log
# ...costs 4.07 seconds
# processing file: 20170413_3_play.log
# ...costs 3.78 seconds
# processing file: 20170414_1_play.log
# C:\Users\Sean\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ...costs 1.90 seconds
# processing file: 20170414_2_play.log
# C:\Users\Sean\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ...costs 2.40 seconds
# processing file: 20170414_3_play.log
# ...costs 2.11 seconds
# processing file: 20170415_1_play.log
# ...costs 4.41 seconds
# processing file: 20170415_2_play.log
# ...costs 4.08 seconds
# processing file: 20170415_3_play.log
# ...costs 4.75 seconds
# processing file: 20170416_1_play.log
# ...costs 3.79 seconds
# processing file: 20170416_2_play.log
# ...costs 3.88 seconds
# processing file: 20170416_3_play.log
# ...costs 4.57 seconds
# processing file: 20170417_1_play.log
# ...costs 3.31 seconds
# processing file: 20170417_2_play.log
# ...costs 3.16 seconds
# processing file: 20170418_1_play.log
# ...costs 2.74 seconds
# processing file: 20170418_2_play.log
# ...costs 3.32 seconds
# processing file: 20170418_3_play.log
# ...costs 3.31 seconds
# processing file: 20170419_1_play.log
# ...costs 3.67 seconds
# processing file: 20170419_2_play.log
# ...costs 3.61 seconds
# processing file: 20170419_3_play.log
# ...costs 3.21 seconds
# processing file: 20170420_1_play.log
# ...costs 8.02 seconds
# processing file: 20170420_2_play.log
# ...costs 2.58 seconds
# processing file: 20170420_3_play.log
# ...costs 2.74 seconds
# processing file: 20170421_1_play.log
# ...costs 2.53 seconds
# processing file: 20170421_2_play.log
# ...costs 2.70 seconds
# processing file: 20170421_3_play.log
# ...costs 2.59 seconds
# processing file: 20170422_1_play.log
# ...costs 3.60 seconds
# processing file: 20170422_2_play.log
# ...costs 3.78 seconds
# processing file: 20170422_3_play.log
# ...costs 3.14 seconds
# processing file: 20170423_1_play.log
# ...costs 2.86 seconds
# processing file: 20170423_2_play.log
# ...costs 2.20 seconds
# processing file: 20170423_3_play.log
# ...costs 2.85 seconds
# processing file: 20170424_1_play.log
# ...costs 2.02 seconds
# processing file: 20170424_2_play.log
# ...costs 0.27 seconds
# processing file: 20170424_3_play.log
# ...costs 2.49 seconds
# processing file: 20170425_1_play.log
# ...costs 2.99 seconds
# processing file: 20170425_2_play.log
# ...costs 2.72 seconds
# processing file: 20170425_3_play.log
# ...costs 2.70 seconds
# processing file: 20170426_1_play.log
# ...costs 5.60 seconds
# processing file: 20170426_2_play.log
# ...costs 3.93 seconds
# processing file: 20170426_3_play.log
# ...costs 4.78 seconds
# processing file: 20170427_1_play.log
# C:\Users\Sean\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (2,3,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ...costs 2.74 seconds
# processing file: 20170427_2_play.log
# ...costs 3.15 seconds
# processing file: 20170427_3_play.log
# ...costs 4.91 seconds
# processing file: 20170428_1_play.log
# ...costs 4.57 seconds
# processing file: 20170428_2_play.log
# ...costs 2.64 seconds
# processing file: 20170428_3_play.log
# ...costs 2.55 seconds
# processing file: 20170429_1_play.log
# ...costs 3.35 seconds
# processing file: 20170429_2_play.log
# ...costs 2.79 seconds
# processing file: 20170429_3_play.log
# ...costs 3.17 seconds
# processing file: 20170430_1_play.log
# ...costs 3.28 seconds
# processing file: 20170430_2_play.log
# ...costs 2.77 seconds
# processing file: 20170430_3_play.log
# ...costs 2.77 seconds
# processing file: 20170501_1_play.log
# ...costs 3.18 seconds
# processing file: 20170501_2_play.log
# ...costs 5.09 seconds
# processing file: 20170501_3_play.log
# ...costs 2.62 seconds
# processing file: 20170502_1_play.log
# ...costs 2.39 seconds
# processing file: 20170502_2_play.log
# ...costs 2.23 seconds
# processing file: 20170502_3_play.log
# ...costs 2.56 seconds
# processing file: 20170503_1_play.log
# ...costs 2.36 seconds
# processing file: 20170503_2_play.log
# ...costs 2.49 seconds
# processing file: 20170503_3_play.log
# ...costs 2.26 seconds
# processing file: 20170504_1_play.log
# ...costs 2.96 seconds
# processing file: 20170504_2_play.log
# ...costs 5.61 seconds
# processing file: 20170504_3_play.log
# ...costs 2.29 seconds
# processing file: 20170505_1_play.log
# ...costs 2.46 seconds
# processing file: 20170505_2_play.log
# ...costs 2.55 seconds
# processing file: 20170505_3_play.log
# ...costs 5.14 seconds
# processing file: 20170506_1_play.log
# ...costs 2.38 seconds
# processing file: 20170506_2_play.log
# ...costs 3.46 seconds
# processing file: 20170506_3_play.log
# ...costs 3.57 seconds
# processing file: 20170507_1_play.log
# ...costs 4.36 seconds
# processing file: 20170507_2_play.log
# ...costs 4.13 seconds
# processing file: 20170507_3_play.log
# ...costs 3.98 seconds
# processing file: 20170508_1_play.log
# ...costs 3.56 seconds
# processing file: 20170508_2_play.log
# ...costs 2.83 seconds
# processing file: 20170508_3_play.log
# ...costs 2.26 seconds
# processing file: 20170509_1_play.log
# ...costs 2.44 seconds
# processing file: 20170509_2_play.log
# ...costs 2.81 seconds
# processing file: 20170509_3_play.log
# ...costs 3.28 seconds
# processing file: 20170510_1_play.log
# ...costs 2.38 seconds
# processing file: 20170510_2_play.log
# ...costs 2.24 seconds
# processing file: 20170510_3_play.log
# ...costs 2.14 seconds
# processing file: 20170511_1_play.log
# ...costs 2.35 seconds
# processing file: 20170511_2_play.log
# ...costs 2.11 seconds
# processing file: 20170511_3_play.log
# ...costs 2.36 seconds
# processing file: 20170512_1_play.log
# ...costs 2.51 seconds
# processing file: 20170512_2_play.log
# ...costs 2.48 seconds
# processing file: 20170512_3_play.log
# ...costs 2.25 seconds
# (40197, 10)

# %%
df_device.device.value_counts()
# Out:
# 薛之谦                                     2053
# 梦然                                      1521
# mc                                      1309
# 云菲菲                                     1170
# 苏勒亚其其格                                  1016
# 庄心妍                                      880
# 王冕                                       861
# 经典老歌                                     584
# 汪苏泷                                      548
# 铃声                                       527
# 乌兰图雅                                     521
# TFBOYS                                   507
# 儿童歌曲                                     459
# 张碧晨                                      446
# Beyond                                   434
# 杨洋                                       412
# 网络歌手                                     359
# 那英                                       354
# 朴树                                       335
# Delacey                                  292
# G.E.M.邓紫棋                                289
# 李荣浩                                      275
# 任妙音&amp;何鹏                               272
# 刘德华                                      272
# 任妙音                                      254
# 张杰                                       250
# Mc天佑                                     238
# 严艺丹                                      227
# 葛林                                       227
# 儿歌大全                                     222
#                                         ...
# Depapepe                                   1
# 有一天我要去远方(44秒铃声版)                           1
# 哈琳                                         1
# 吴听彻                                        1
# 瞿颖[傻白甜的红桃皇后]&amp;进击的女帝                     1
# Ramin Djawadi&amp;Tom Morello              1
# 平安                                         1
# Psy                                        1
# 李光                                         1
# 蒙克&amp;乌兰托娅                                1
# 金秀贤                                        1
# 阿木                                         1
# 薛小毅                                        1
# 巨鹿(1分16秒铃声版)                               1
# 陈赫                                         1
# 爱是一首歌(老师版 29秒铃声版)-(综艺《音乐大师课》第二学年主题曲)       1
# 少军                                         1
# 苏打绿                                        1
# 欧豪&amp;胡夏&amp;杨洋[演员]                       1
# 陈洁仪                                        1
# 筷子兄弟&amp;凤凰传奇&amp;DJ杰森                     1
# 王志文&amp;江珊                                 1
# 广智                                         1
# Eminem Rihanna                             1
# 谭晶&amp;陈奕迅                                 1
# 龙梅子&amp;王麟                                 1
# 徐怀钰                                        1
# 江美琪                                        1
# 童可可                                        1
# The Cascades                               1
# Name: device, Length: 1266, dtype: int64

# %%
df_mc_log = df_device.loc[df_device.device.apply(lambda x: x== 'mc')]
df_mc_log.head()
# Out:
#                uid device      song_id song_type       song_name  \
# 95600  1.68577e+08     mc  1.25985e+07         2  Love You Right
# 95705  1.68577e+08     mc  1.25985e+07         2  Love You Right
# 97451  1.68577e+08     mc       616808         2            勿忘心安
# 97475  1.68577e+08     mc  2.69287e+06         2           Today
# 97508  1.68577e+08     mc  5.07826e+06         2              情歌
#
#               singer play_time song_length paid_flag            file_name
# 95600          Caius       NaN           0         0  20170330_3_play.log
# 95705          Caius       NaN           0         0  20170330_3_play.log
# 97451             张杰       NaN         249         0  20170330_3_play.log
# 97475  G-Dragon&Nell       NaN         221         0  20170330_3_play.log
# 97508             群星       NaN         260         0  20170330_3_play.log

# %%
df_mc_log.shape
# Out:
# (1309, 10)

# %%
df_mc_log.groupby('uid').size()
# Out:
# uid
# 47342301.0     652
# 168165825.0     92
# 168166684.0    100
# 168170738.0    242
# 168171292.0     17
# 168171514.0     16
# 168576820.0      2
# 168577045.0     20
# 168577224.0     27
# dtype: int64

# %%
# active and churns among them
cutoff = '20170422'
df_mc_log['before_cutoff'] = df_mc_log.file_name.apply(lambda x: x[:8]<cutoff)
# Out:
# C:\Users\Sean\Anaconda2\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_mc_log.head()
# Out:
#                uid device      song_id song_type       song_name  \
# 95600  1.68577e+08     mc  1.25985e+07         2  Love You Right
# 95705  1.68577e+08     mc  1.25985e+07         2  Love You Right
# 97451  1.68577e+08     mc       616808         2            勿忘心安
# 97475  1.68577e+08     mc  2.69287e+06         2           Today
# 97508  1.68577e+08     mc  5.07826e+06         2              情歌
#
#               singer play_time song_length paid_flag            file_name  \
# 95600          Caius       NaN           0         0  20170330_3_play.log
# 95705          Caius       NaN           0         0  20170330_3_play.log
# 97451             张杰       NaN         249         0  20170330_3_play.log
# 97475  G-Dragon&Nell       NaN         221         0  20170330_3_play.log
# 97508             群星       NaN         260         0  20170330_3_play.log
#
#        before_cut_off  before_cutoff
# 95600            True           True
# 95705            True           True
# 97451            True           True
# 97475            True           True
# 97508            True           True

# %%
sum(df_mc_log.groupby('uid').sum()['before_cutoff']<=3)
# Out:
# 1

# %%
df_mc_log['after_cutoff'] = df_mc_log.file_name.apply(lambda x: x[:8]>=cutoff)
# Out:
# C:\Users\Sean\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
sum(df_mc_log.groupby('uid').sum()['before_cutoff']>0)
# Out:
# 9

# %% [markdown]
#     There is no churn in mc users.

# %%
df_mc_log.to_csv('C:\\Users\\Sean\\Documents\\BitTiger\\Capston_music_player_python\\mc_users_log.csv')
df_mc_log.to_pickle('C:\\Users\\Sean\\Documents\\BitTiger\\Capston_music_player_python\\mc_users_log.pkl')
